# %%
# !git clone https://github.com/veronika-ilioska/waste-classification.git
# %cd waste-classification
# Out:
# Cloning into 'waste-classification'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 91 (delta 0), reused 4 (delta 0), pack-reused 84 (from 1)
# Receiving objects: 100% (91/91), 68.14 MiB | 25.06 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# /content/waste-classification

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 131.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 4.0 MB/s eta 0:00:00
# ...

# %%
# !python YOLOv11/train_ecodetect_yolov11.py --check-only
# Out:
# ...
# 100% 151M/151M [00:01<00:00, 117MB/s]
# Extracting files...
# Dataset root: /root/.cache/kagglehub/datasets/ahsan71/ecodetect-recyclable-waste-detection-dataset/versions/5
# Prepared data.yaml: artifacts/ecodetect/yolov11/train/ecodetect_data.yaml
# Classes: ['aluminum', 'paper', 'plastic']
# train: 1750 images, 1750 labels
# valid: 75 images, 75 labels
# test: 75 images, 75 labels
# Check complete. No training was run.

# %%
# !python YOLOv11/train_ecodetect_yolov11.py --device cpu --epochs 5
# Out:
# Dataset root: /root/.cache/kagglehub/datasets/ahsan71/ecodetect-recyclable-waste-detection-dataset/versions/5
# Prepared data.yaml: artifacts/ecodetect/yolov11/train/ecodetect_data.yaml
# Classes: ['aluminum', 'paper', 'plastic']
# train: 1750 images, 1750 labels
# valid: 75 images, 75 labels
# test: 75 images, 75 labels
# Ultralytics 8.4.79 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from IPython.display import Image, display

display(Image("/content/waste-classification/runs/detect/artifacts/ecodetect/yolov11/train_test/BoxF1_curve.png"))
display(Image("/content/waste-classification/runs/detect/artifacts/ecodetect/yolov11/train_test/BoxPR_curve.png"))
display(Image("/content/waste-classification/runs/detect/artifacts/ecodetect/yolov11/train_test/BoxP_curve.png"))
display(Image("/content/waste-classification/runs/detect/artifacts/ecodetect/yolov11/train_test/BoxR_curve.png"))
display(Image("/content/waste-classification/runs/detect/artifacts/ecodetect/yolov11/train_test/confusion_matrix.png"))
display(Image("/content/waste-classification/runs/detect/artifacts/ecodetect/yolov11/train_test/confusion_matrix_normalized.png"))

# %%
display(Image("/content/waste-classification/runs/detect/artifacts/ecodetect/yolov11/train/results.png"))

# %%
display(Image("/content/waste-classification/runs/detect/artifacts/ecodetect/yolov11/train_test/val_batch2_pred.jpg"))

# %%
import json

with open("/content/waste-classification/runs/detect/artifacts/ecodetect/yolov11/train/evaluation_summary.json") as f:
    summary = json.load(f)

summary["metrics"]
# Out:
# {'map50_95': 0.3347148961322184,
#  'map50': 0.46743815840463626,
#  'map75': 0.4001055623829095,
#  'mean_precision': 0.3763434580905814,
#  'mean_recall': 0.5939726073102781}
